# %% [markdown]
# # Dia 2 Libreta 6
# En esta libreta usaremos un clasificador para detectar rostros en imagenes; despues realizaran el ejercicio de tomar una foto de su rostro con el dispositivo, extraerlo del mismo a la mnaquina y aplciar el detector.
#
# Finalmente, trataremos de implementarlo en el dispositivo...
#
# Algo de informacion [tomada de este sitio](https://realpython.com/blog/python/face-recognition-with-python/)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import sys, os, re, time
import numpy as np
import cv2

# %%
pic = os.path.join('.','carota.jpg')#'ZuzanaB.jpg')

# %%
img=cv2.imread(pic)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
caras_cascada=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

caras = caras_cascada.detectMultiScale(gray, 1.7, 5)

print "Encontramos {0} faces!".format(len(caras))
# Out:
# Encontramos 0 faces!

# %%
i = img.copy()
for (x,y,w,h) in caras:
    cv2.rectangle(i, (x,y), (x+w,y+h), (0,255,0), 2)

plt.imshow(i)

# %%
import android
droide=android.Android()

# %%
droide.ttsSpeak("Hola. Di wisky.")

droide.cameraCapturePicture('/sdcard/DCIM/CAMERA/carota.jpg')

droide.ttsSpeak("Listo.")
# Out:
# Result(id=1, result={u'takePicture': True, u'autoFocus': True, u'cameraId': 0}, error=None)

# %%
# !adb pull /sdcard/DCIM/CAMERA/carota.jpg
# Out:
# 3768 KB/s (16798 bytes in 0.004s)

# %%
droide.getLaunchableApplications().result
# Out:
# {u'ADO M\xf3vil': u'com.apptizzy.ado.activities.SplashScreen',
#  u'Ajustes': u'com.android.settings.Settings',
#  u'Ajustes de Google': u'com.google.android.gms.app.settings.GoogleSettingsActivity',
#  u'Audio Record': u'mx.lania.gudini.audiorecord.MainActivity',
#  u'Ayuda HTC': u'com.htc.guide.MainActivity',
#  u'BBM': u'com.bbm.ui.activities.StartupActivity',
#  u'Bolsa': u'com.htc.stock.ui.HomeActivity',
#  u'B\xfasqueda por voz': u'com.google.android.googlequicksearchbox.VoiceSearchActivity',
#  u'Calcula IMC': u'mx.lania.calculaimc.CalculaMasaActivity',
#  u'Calculadora': u'com.htc.calculator.Calculator',
#  u'Calcular Cuenta': u'mx.lania.calcularcuenta.MainActivity',
#  u'Calendario': u'com.htc.calendar.CalendarActivityMain',
#  u'Car': u'com.htc.AutoMotive.carousel.MainActivity',
#  u'Chrome': u'com.google.android.apps.chrome.Main',
#  u'Cin\xe9polis': u'com.ia.cinepolis.android.smartphone.SplashScreen',
#  u'ClaroVideo': u'com.clarovideo.app.ui.activities.SplashActivity',
#  u'Clarojuegos': u'com.gameloft.android.gdc.GDCMainShop',
#  u'Clarom\xfasica': u'com.telcel.imk.MainActivity',
#  u'Clean Master': u'com.keniu.security.main.MainActivity',
#  u'Clima': u'com.htc.Weather.WeatherEntry',
#  u'Configurar': u'com.htc.android.htcsetupwizard.SetupWizardActivity',
#  u'Consumo': u'telcel.net.MainActivityTab',
#  u'Consumo datos y llamadas': u'com.trecone.SplashActivity',
#  u'Contactos': u'com.htc.contacts.BrowseLayerCarouselActivity',
#  u'Copia de seguridad HTC': u'com.htc.backup.oobe.Launcher',
#  u'Correo': u'com.htc.android.mail.MultipleActivitiesMain',
#  u'Crackle': u'com.gotv.crackle.LoadingActivity',
#  u'Crunchyroll': u'com.crunchyroll.crunchyroid.activities.SplashActivity',
#  u'C\xe1mara': u'com.htc.camera.CameraEntry',
#  u'DAISUKI': u'net.daisuki.daisukiapp.SplashActivity',
#  u'Databases SQLite': u'mx.lania.databasessqlite.MainActivity',
#  u'Descargas': u'com.android.providers.downloads.ui.DownloadList',
#  u'Drive': u'com.google.android.apps.docs.app.NewMainProxyActivity',
#  u'Editor de foto': u'com.htc.photoenhancer.LandingPage',
#  u'Entrada de japon\xe9s de Google': u'com.google.android.inputmethod.japanese.LauncherActivity',
#  u'FOX Play': u'com.accedo.fox.android.SplashActivity',
#  u'Facebook': u'com.facebook.katana.LoginActivity',
#  u'Fantasica': u'com.ngmoco.marketingapp.PackageApplication',
#  u'Files': u'mx.lania.files.MainActivity',
#  u'Filtro ponderado': u'mx.lania.gudini.filtroponderado.MainActivity',
#  u'GPS Telcel': u'com.telenav.app.android.gpstelcel.TeleNav',
#  u'Galer\xeda': u'com.htc.album.AlbumMain.ActivityMainTabHost',
#  u'Gmail': u'com.google.android.gm.ConversationListActivityGmail',
#  u'Google': u'com.google.android.googlequicksearchbox.SearchActivity',
#  u'Google+': u'com.google.android.apps.plus.phone.HomeActivity',
#  u'Grabador de voz': u'com.htc.soundrecorder.SoundRecorderBG',
#  u'HTC Dot View': u'com.htc.dotmatrix.ui.DotViewSettingActivity',
#  u'Hangouts': u'com.google.android.talk.SigningInActivity',
#  u'Indoor Maps': u'mx.lania.gudini.indoormaps.MainActivity',
#  u'Instagram': u'com.instagram.android.activity.MainTabActivity',
#  u'Internet': u'com.htc.sense.browser.BrowserActivity',
#  u'LINE': u'jp.naver.line.android.activity.SplashActivity',
#  u'LINE Tools': u'jp.naver.linetools.LinetoolsActivity',
#  u'Lifeline': u'com.bigfishgames.lifeline.SplashActivity',
#  u'LinkedIn': u'com.linkedin.android.authenticator.LaunchActivity',
#  u'Los 40': u'com.td.prisa.los40.EntryPointActivity',
#  u'Manga': u'com.crmanga.misc.SplashActivity',
#  u'Map': u'mx.lania.gudini.googlemaps.MapsActivity',
#  u'Maps': u'com.google.android.maps.MapsActivity',
#  u'Mensajes': u'com.htc.sense.mms.ui.ConversationList',
#  u'Messenger': u'com.facebook.orca.auth.StartScreenActivity',
#  u'Mi Telcel': u'com.speedymovil.wire.Login',
#  u'Mobizen': u'com.rsupport.mvagent.ui.activity.splash.SplashActivity',
#  u'Music Player': u'mx.lania.gudini.musicplayer.MainActivity',
#  u'M\xfasica': u'com.htc.music.browserlayer.MusicBrowserTabActivity',
#  u'Netflix': u'com.netflix.mediaclient.ui.launch.UIWebViewActivity',
#  u'Noticias y el tiempo': u'com.google.android.apps.genie.geniewidget.activities.NewsActivity',
#  u'Notificaci\xf3n de tiempo de conversaci\xf3n': u'toolbox.m.notification.airtime.MySetting',
#  u'Onefootball': u'de.motain.iliga.activity.SplashScreenActivity',
#  u'Outlook': u'com.microsoft.office.outlook.MainActivity',
#  u'POLARIS \nOffice 5': u'com.infraware.polarisoffice5.OfficeHomeActivity',
#  u'Play Juegos': u'com.google.android.gms.games.ui.destination.main.MainActivity',
#  u'Play Kiosco': u'com.google.apps.dots.android.app.activity.CurrentsStartActivity',
#  u'Play Libros': u'com.google.android.apps.books.app.BooksActivity',
#  u'Play M\xfasica': u'com.android.music.activitymanagement.TopLevelActivity',
#  u'Play Pel\xedculas': u'com.google.android.youtube.videos.EntryPoint',
#  u'Play Store': u'com.android.vending.AssetBrowserActivity',
#  u'Pok\xe9mon Shuffle': u'com.havok.Vision.NativeLibLoader',
#  u'Portal Claroideas': u'com.portal.Portal',
#  u'Preference Fragment': u'mx.lania.preferencefragment.MainActivity',
#  u'Preguntados': u'com.etermax.preguntados.ui.SplashActivity_',
#  u'Python for Android': u'com.googlecode.pythonforandroid.PythonMain',
#  u'Radio FM': u'com.htc.fm.ap.activity.FMRadioMain',
#  u'Rage of Bahamut': u'com.mobage.ww.a692.Bahamut_Android.SplashActivity',
#  u'Reloj': u'com.htc.android.worldclock.WorldClockTabControl',
#  u'SIM Telcel': u'com.android.stk.StkLauncherActivity',
#  u'SL4A': u'com.googlecode.android_scripting.activity.ScriptManager',
#  u'Seg. M\xf3vil': u'com.netqin.antivirus.AntiVirusSplash',
#  u'Sensor Activity': u'mx.lania.gudini.sensoractivity.SensorActivity',
#  u'Sensor Event Monitoring': u'mx.lania.gudini.sensoreventmonitoring.MainActivity',
#  u'SensorList': u'mx.lania.gudini.sensorlist.MainActivity',
#  u'Shazam': u'com.shazam.android.activities.SplashActivity',
#  u'Shouts': u'net.taringa.mobile.SplashActivity',
#  u'Skype': u'com.skype.raider.Main',
#  u'Spotify': u'com.spotify.music.MainActivity',
#  u'Sugerencias y Ayuda': u'com.htc.showme.ui.MainPage',
#  u'Swype + Dragon': u'com.nuance.swype.input.settings.SettingsDispatch',
#  u'Tareas': u'com.htc.task.TaskListViewActivity',
#  u'Teclado de Google': u'com.android.inputmethod.latin.setup.SetupActivity',
#  u'Telcel': u'com.telcel.contenedor.gui.activities.AppsContainerActivity',
#  u'Telegram': u'org.telegram.ui.LaunchActivity',
#  u'Tel\xe9fono': u'com.htc.contacts.DialerTabActivity',
#  u'Test Location': u'mx.lania.gudini.testlocation.MainActivity',
#  u'That Level Again': u'ru.iamtagir.game.android.AndroidLauncher',
#  u'Traductor': u'com.google.android.apps.translate.TranslateActivity',
#  u'Tus Temas': u'com.htc.themepicker.AssetBrowsingActivity',
#  u'Twitter': u'com.twitter.android.StartActivity',
#  u'Using Preferences': u'mx.lania.usingpreferences.MainActivity',
#  u'Using Preferences 2': u'mx.lania.usingpreferences2.MainActivity',
#  u'Video Player': u'mx.lania.gudini.videoplayer.MainActivity',
#  u'Viewster': u'com.viewster.android.ui.start.StartActivity',
#  u'Viki': u'com.viki.android.SplashActivity',
#  u'Waze': u'com.waze.FreeMapAppActivity',
#  u'WeChat': u'com.tencent.mm.ui.LauncherUI',
#  u'WebServices': u'mx.lania.webservices.MainActivity',
#  u'WhatsApp': u'com.whatsapp.Main',
#  u'Yahoo Mail': u'com.yahoo.mobile.client.android.mail.activity.MainActivity',
#  u'YouTube': u'com.google.android.youtube.app.honeycomb.Shell$HomeActivity'}

# %%
import android
droide=android.Android()

droide.ttsSpeak("Hola. Di wisky.")

droide.cameraCapturePicture('/sdcard/DCIM/CAMERA/carota.jpg')

droide.ttsSpeak("Listo.")

# %%
# !adb pull /sdcard/DCIM/CAMERA/carota.jpg

# %%
pic = os.path.join('.','carota.jpg')

img=cv2.imread(pic)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

caras_cascada=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
caras = caras_cascada.detectMultiScale(gray, 1.7, 5)
print "Encontramos {0} faces!".format(len(caras))

# %%
i = img.copy()
for (x,y,w,h) in caras:
    cv2.rectangle(i, (x,y), (x+w,y+h), (0,255,0), 2)

plt.imshow(i)
