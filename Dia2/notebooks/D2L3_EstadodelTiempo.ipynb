# %% [markdown]
# # Dia 2, Libreta 3 Estado del tiempo
# A continuacion vamos a hacer un ejercicio de programacion con Python en la libreta y despues en el dispositivo.
#
# El objetivo de este ejercicio es solicitar la temperatura a un servicio en linea, [weatherunderground](http://www.wunderground.com) utilizando la API del servicio.
#
# ## Buscando informacion en weather underground
#
# Abran el interprete de Python en su dispositivo y escriban lo siguiente:
#
# [vea](http://www.wunderground.com/weather/api/d/docs?d=data/index&MR=1)

# %%
import urllib2
import json

f = urllib2.urlopen('http://api.wunderground.com/api/0def10027afaebb7/geolookup/conditions/forecast/q/Mexico/Mexico.json')
json_string = f.read()
parsed_json = json.loads(json_string)
location = parsed_json['location']['city']
temp_c = parsed_json['current_observation']['temp_c']
print "La temperatura actual en %s es: %s C" % (location, temp_c)
f.close()
# Out:
# La temperatura actual en Mexico es: 19.6 C

# %%
parsed_json
# Out:
# {u'current_observation': {u'UV': u'8.0',
#   u'dewpoint_c': 8,
#   u'dewpoint_f': 47,
#   u'dewpoint_string': u'47 F (8 C)',
#   u'display_location': {u'city': u'Mexico',
#    u'country': u'MX',
#    u'country_iso3166': u'MX',
#    u'elevation': u'2248.00000000',
#    u'full': u'Mexico, Mexico',
#    u'latitude': u'19.43416595',
#    u'longitude': u'-99.13861084',
#    u'magic': u'16',
#    u'state': u'',
#    u'state_name': u'Mexico',
#    u'wmo': u'76679',
#    u'zip': u'00000'},
#   u'estimated': {},
#   u'feelslike_c': u'19.6',
#   u'feelslike_f': u'67.3',
#   u'feelslike_string': u'67.3 F (19.6 C)',
#   u'forecast_url': u'http://www.wunderground.com/global/stations/76679.html',
#   u'heat_index_c': u'NA',
#   u'heat_index_f': u'NA',
#   u'heat_index_string': u'NA',
#   u'history_url': u'http://www.wunderground.com/weatherstation/WXDailyHistory.asp?ID=IDISTRIT44',
#   u'icon': u'mostlycloudy',
#   u'icon_url': u'http://icons.wxug.com/i/c/k/mostlycloudy.gif',
#   u'image': {u'link': u'http://www.wunderground.com',
#    u'title': u'Weather Underground',
#    u'url': u'http://icons.wxug.com/graphics/wu2/logo_130x80.png'},
#   u'local_epoch': u'1446311024',
#   u'local_time_rfc822': u'Sat, 31 Oct 2015 11:03:44 -0600',
#   u'local_tz_long': u'America/Mexico_City',
#   u'local_tz_offset': u'-0600',
#   u'local_tz_short': u'CST',
#   u'nowcast': u'',
#   u'ob_url': u'http://www.wunderground.com/cgi-bin/findweather/getForecast?query=19.403210,-99.142494',
#   u'observation_epoch': u'1446311014',
#   u'observation_location': {u'city': u'Alamos, Ciudad De Mexico',
#    u'country': u'Mexico',
#    u'country_iso3166': u'MX',
#    u'elevation': u'7346 ft',
#    u'full': u'Alamos, Ciudad De Mexico, DISTRITO FEDERAL',
#    u'latitude': u'19.403210',
#    u'longitude': u'-99.142494',
#    u'state': u'DISTRITO FEDERAL'},
#   u'observation_time': u'Last Updated on October 31, 11:03 AM CST',
#   u'observation_time_rfc822': u'Sat, 31 Oct 2015 11:03:34 -0600',
#   u'precip_1hr_in': u'0.00',
#   u'precip_1hr_metric': u' 0',
#   u'precip_1hr_string': u'0.00 in ( 0 mm)',
#   u'precip_today_in': u'0.00',
#   u'precip_today_metric': u'0',
#   u'precip_today_string': u'0.00 in (0 mm)',
#   u'pressure_in': u'30.26',
#   u'pressure_mb': u'1025',
#   u'pressure_trend': u'0',
#   u'relative_humidity': u'48%',
#   u'solarradiation': u'611',
#   u'station_id': u'IDISTRIT44',
#   u'temp_c': 19.6,
#   u'temp_f': 67.3,
#   u'temperature_string': u'67.3 F (19.6 C)',
#   u'visibility_km': u'24.1',
#   u'visibility_mi': u'15.0',
#   u'weather': u'Mostly Cloudy',
#   u'wind_degrees': 115,
#   u'wind_dir': u'ESE',
#   u'wind_gust_kph': u'19.8',
#   u'wind_gust_mph': u'12.3',
#   u'wind_kph': 15.4,
#   u'wind_mph': 9.6,
#   u'wind_string': u'From the ESE at 9.6 MPH Gusting to 12.3 MPH',
#   u'windchill_c': u'NA',
#   u'windchill_f': u'NA',
#   u'windchill_string': u'NA'},
#  u'forecast': {u'simpleforecast': {u'forecastday': [{u'avehumidity': 55,
#      u'avewind': {u'degrees': 182, u'dir': u'S', u'kph': 19, u'mph': 12},
#      u'conditions': u'Chance of a Thunderstorm',
#      u'date': {u'ampm': u'PM',
#       u'day': 31,
#       u'epoch': u'1446339600',
#       u'hour': 19,
#       u'isdst': u'0',
#       u'min': u'00',
#       u'month': 10,
#       u'monthname': u'October',
#       u'monthname_short': u'Oct',
#       u'pretty': u'7:00 PM CST on October 31, 2015',
#       u'sec': 0,
#       u'tz_long': u'America/Mexico_City',
#       u'tz_short': u'CST',
#       u'weekday': u'Saturday',
#       u'weekday_short': u'Sat',
#       u'yday': 303,
#       u'year': 2015},
#      u'high': {u'celsius': u'23', u'fahrenheit': u'73'},
#      u'icon': u'chancetstorms',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      u'low': {u'celsius': u'13', u'fahrenheit': u'56'},
#      u'maxhumidity': 0,
#      u'maxwind': {u'degrees': 182, u'dir': u'S', u'kph': 24, u'mph': 15},
#      u'minhumidity': 0,
#      u'period': 1,
#      u'pop': 40,
#      u'qpf_allday': {u'in': 0.01, u'mm': 0},
#      u'qpf_day': {u'in': 0.01, u'mm': 0},
#      u'qpf_night': {u'in': 0.0, u'mm': 0},
#      u'skyicon': u'',
#      u'snow_allday': {u'cm': 0.0, u'in': 0.0},
#      u'snow_day': {u'cm': 0.0, u'in': 0.0},
#      u'snow_night': {u'cm': 0.0, u'in': 0.0}},
#     {u'avehumidity': 66,
#      u'avewind': {u'degrees': 19, u'dir': u'NNE', u'kph': 11, u'mph': 7},
#      u'conditions': u'Chance of a Thunderstorm',
#      u'date': {u'ampm': u'PM',
#       u'day': 1,
#       u'epoch': u'1446426000',
#       u'hour': 19,
#       u'isdst': u'0',
#       u'min': u'00',
#       u'month': 11,
#       u'monthname': u'November',
#       u'monthname_short': u'Nov',
#       u'pretty': u'7:00 PM CST on November 01, 2015',
#       u'sec': 0,
#       u'tz_long': u'America/Mexico_City',
#       u'tz_short': u'CST',
#       u'weekday': u'Sunday',
#       u'weekday_short': u'Sun',
#       u'yday': 304,
#       u'year': 2015},
#      u'high': {u'celsius': u'21', u'fahrenheit': u'69'},
#      u'icon': u'chancetstorms',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      u'low': {u'celsius': u'13', u'fahrenheit': u'56'},
#      u'maxhumidity': 0,
#      u'maxwind': {u'degrees': 19, u'dir': u'NNE', u'kph': 16, u'mph': 10},
#      u'minhumidity': 0,
#      u'period': 2,
#      u'pop': 90,
#      u'qpf_allday': {u'in': 0.35, u'mm': 9},
#      u'qpf_day': {u'in': 0.3, u'mm': 8},
#      u'qpf_night': {u'in': 0.05, u'mm': 1},
#      u'skyicon': u'',
#      u'snow_allday': {u'cm': 0.0, u'in': 0.0},
#      u'snow_day': {u'cm': 0.0, u'in': 0.0},
#      u'snow_night': {u'cm': 0.0, u'in': 0.0}},
#     {u'avehumidity': 64,
#      u'avewind': {u'degrees': 122, u'dir': u'ESE', u'kph': 14, u'mph': 9},
#      u'conditions': u'Chance of a Thunderstorm',
#      u'date': {u'ampm': u'PM',
#       u'day': 2,
#       u'epoch': u'1446512400',
#       u'hour': 19,
#       u'isdst': u'0',
#       u'min': u'00',
#       u'month': 11,
#       u'monthname': u'November',
#       u'monthname_short': u'Nov',
#       u'pretty': u'7:00 PM CST on November 02, 2015',
#       u'sec': 0,
#       u'tz_long': u'America/Mexico_City',
#       u'tz_short': u'CST',
#       u'weekday': u'Monday',
#       u'weekday_short': u'Mon',
#       u'yday': 305,
#       u'year': 2015},
#      u'high': {u'celsius': u'23', u'fahrenheit': u'74'},
#      u'icon': u'chancetstorms',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      u'low': {u'celsius': u'11', u'fahrenheit': u'52'},
#      u'maxhumidity': 0,
#      u'maxwind': {u'degrees': 122, u'dir': u'ESE', u'kph': 16, u'mph': 10},
#      u'minhumidity': 0,
#      u'period': 3,
#      u'pop': 50,
#      u'qpf_allday': {u'in': 0.09, u'mm': 2},
#      u'qpf_day': {u'in': 0.09, u'mm': 2},
#      u'qpf_night': {u'in': 0.01, u'mm': 0},
#      u'skyicon': u'',
#      u'snow_allday': {u'cm': 0.0, u'in': 0.0},
#      u'snow_day': {u'cm': 0.0, u'in': 0.0},
#      u'snow_night': {u'cm': 0.0, u'in': 0.0}},
#     {u'avehumidity': 58,
#      u'avewind': {u'degrees': 121, u'dir': u'ESE', u'kph': 10, u'mph': 6},
#      u'conditions': u'Chance of a Thunderstorm',
#      u'date': {u'ampm': u'PM',
#       u'day': 3,
#       u'epoch': u'1446598800',
#       u'hour': 19,
#       u'isdst': u'0',
#       u'min': u'00',
#       u'month': 11,
#       u'monthname': u'November',
#       u'monthname_short': u'Nov',
#       u'pretty': u'7:00 PM CST on November 03, 2015',
#       u'sec': 0,
#       u'tz_long': u'America/Mexico_City',
#       u'tz_short': u'CST',
#       u'weekday': u'Tuesday',
#       u'weekday_short': u'Tue',
#       u'yday': 306,
#       u'year': 2015},
#      u'high': {u'celsius': u'24', u'fahrenheit': u'75'},
#      u'icon': u'chancetstorms',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      u'low': {u'celsius': u'12', u'fahrenheit': u'53'},
#      u'maxhumidity': 0,
#      u'maxwind': {u'degrees': 121, u'dir': u'ESE', u'kph': 16, u'mph': 10},
#      u'minhumidity': 0,
#      u'period': 4,
#      u'pop': 60,
#      u'qpf_allday': {u'in': 0.09, u'mm': 2},
#      u'qpf_day': {u'in': 0.07, u'mm': 2},
#      u'qpf_night': {u'in': 0.02, u'mm': 1},
#      u'skyicon': u'',
#      u'snow_allday': {u'cm': 0.0, u'in': 0.0},
#      u'snow_day': {u'cm': 0.0, u'in': 0.0},
#      u'snow_night': {u'cm': 0.0, u'in': 0.0}}]},
#   u'txt_forecast': {u'date': u'9:54 AM CST',
#    u'forecastday': [{u'fcttext': u'Scattered showers and thunderstorms. High 73F. Winds S at 10 to 15 mph. Chance of rain 40%.',
#      u'fcttext_metric': u'Scattered showers and thunderstorms. High 23C. Winds S at 15 to 30 km/h. Chance of rain 40%.',
#      u'icon': u'chancetstorms',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      u'period': 0,
#      u'pop': u'40',
#      u'title': u'Saturday'},
#     {u'fcttext': u'Cloudy skies early, followed by partial clearing. Low 56F. Winds SSW at 5 to 10 mph.',
#      u'fcttext_metric': u'Cloudy skies early, then partly cloudy after midnight. Low 13C. Winds S at 10 to 15 km/h.',
#      u'icon': u'nt_partlycloudy',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/nt_partlycloudy.gif',
#      u'period': 1,
#      u'pop': u'20',
#      u'title': u'Saturday Night'},
#     {u'fcttext': u'Partly cloudy skies during the morning hours. Thunderstorms likely in the afternoon. High 69F. Winds NNE at 5 to 10 mph. Chance of rain 90%.',
#      u'fcttext_metric': u'Partly cloudy in the morning. Thunderstorms developing later in the day. High around 20C. Winds NNE at 10 to 15 km/h. Chance of rain 90%.',
#      u'icon': u'chancetstorms',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      u'period': 2,
#      u'pop': u'90',
#      u'title': u'Sunday'},
#     {u'fcttext': u'Thunderstorms during the evening followed by occasional showers overnight. Low 56F. Winds NNW at 5 to 10 mph. Chance of rain 80%.',
#      u'fcttext_metric': u'Thunderstorms during the evening followed by occasional showers overnight. Low 13C. Winds NNW at 10 to 15 km/h. Chance of rain 80%.',
#      u'icon': u'nt_tstorms',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/nt_tstorms.gif',
#      u'period': 3,
#      u'pop': u'80',
#      u'title': u'Sunday Night'},
#     {u'fcttext': u'Showers early then scattered thunderstorms developing later in the day. High 74F. Winds ESE at 5 to 10 mph. Chance of rain 50%.',
#      u'fcttext_metric': u'Showers early then scattered thunderstorms developing later in the day. High 23C. Winds ESE at 10 to 15 km/h. Chance of rain 40%.',
#      u'icon': u'chancetstorms',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      u'period': 4,
#      u'pop': u'50',
#      u'title': u'Monday'},
#     {u'fcttext': u'Showers in the evening, then partly cloudy overnight. Low 52F. Winds WSW at 5 to 10 mph. Chance of rain 40%.',
#      u'fcttext_metric': u'Showers in the evening, then partly cloudy overnight. Low 12C. Winds WSW at 10 to 15 km/h. Chance of rain 40%.',
#      u'icon': u'nt_chancerain',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/nt_chancerain.gif',
#      u'period': 5,
#      u'pop': u'40',
#      u'title': u'Monday Night'},
#     {u'fcttext': u'Partial cloudiness early, with scattered showers and thunderstorms in the afternoon. High near 75F. Winds ESE at 5 to 10 mph. Chance of rain 60%.',
#      u'fcttext_metric': u'Partly cloudy early. Scattered thunderstorms developing in the afternoon. High 24C. Winds ESE at 10 to 15 km/h. Chance of rain 60%.',
#      u'icon': u'chancetstorms',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/chancetstorms.gif',
#      u'period': 6,
#      u'pop': u'60',
#      u'title': u'Tuesday'},
#     {u'fcttext': u'Showers in the evening, then partly cloudy overnight. Low 53F. Winds WSW at 5 to 10 mph. Chance of rain 40%.',
#      u'fcttext_metric': u'Rain showers early with clearing later at night. Low 12C. Winds WSW at 10 to 15 km/h. Chance of rain 40%.',
#      u'icon': u'nt_chancerain',
#      u'icon_url': u'http://icons.wxug.com/i/c/k/nt_chancerain.gif',
#      u'period': 7,
#      u'pop': u'40',
#      u'title': u'Tuesday Night'}]}},
#  u'location': {u'city': u'Mexico',
#   u'country': u'MX',
#   u'country_iso3166': u'MX',
#   u'country_name': u'Mexico',
#   u'l': u'/q/zmw:00000.16.76679',
#   u'lat': u'19.43416595',
#   u'lon': u'-99.13861084',
#   u'magic': u'16',
#   u'nearby_weather_stations': {u'airport': {u'station': [{u'city': u'',
#       u'country': u'',
#       u'icao': u'',
#       u'lat': u'',
#       u'lon': u'',
#       u'state': u''},
#      {u'city': u'Mexico City Airport',
#       u'country': u'MX',
#       u'icao': u'MMMX',
#       u'lat': u'19.43000031',
#       u'lon': u'-99.09999847',
#       u'state': u''},
#      {u'city': u'Toluca Jose Maria',
#       u'country': u'MX',
#       u'icao': u'MMTO',
#       u'lat': u'19.33709908',
#       u'lon': u'-99.56600189',
#       u'state': u''}]},
#    u'pws': {u'station': [{u'city': u'Centro',
#       u'country': u'MX',
#       u'distance_km': 0,
#       u'distance_mi': 0,
#       u'id': u'ICENTRO5',
#       u'lat': 19.4342,
#       u'lon': -99.138603,
#       u'neighborhood': u'Centro',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 0,
#       u'distance_mi': 0,
#       u'id': u'ICIUDADD45',
#       u'lat': 19.4342,
#       u'lon': -99.138603,
#       u'neighborhood': u'Centro',
#       u'state': u''},
#      {u'city': u'M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 3,
#       u'distance_mi': 2,
#       u'id': u'IMXICO3',
#       u'lat': 19.433784,
#       u'lon': -99.170761,
#       u'neighborhood': u'Cuauht\xe9moc',
#       u'state': u''},
#      {u'city': u'Ciudad De Mexico',
#       u'country': u'Mexico',
#       u'distance_km': 3,
#       u'distance_mi': 2,
#       u'id': u'IDISTRIT44',
#       u'lat': 19.40321,
#       u'lon': -99.142494,
#       u'neighborhood': u'Alamos',
#       u'state': u'DISTRITO FEDERAL'},
#      {u'city': u'Mexico City',
#       u'country': u'MX',
#       u'distance_km': 3,
#       u'distance_mi': 2,
#       u'id': u'IMEXICOC15',
#       u'lat': 19.422491,
#       u'lon': -99.17189,
#       u'neighborhood': u'Ju\xe1rez',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 3,
#       u'distance_mi': 2,
#       u'id': u'ICIUDADD33',
#       u'lat': 19.414846,
#       u'lon': -99.168022,
#       u'neighborhood': u'Hip\xf3dromo',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'M\xe9XICO',
#       u'distance_km': 3,
#       u'distance_mi': 2,
#       u'id': u'IDISTRIT48',
#       u'lat': 19.410732,
#       u'lon': -99.165031,
#       u'neighborhood': u'Col. Roma Norte',
#       u'state': u'DISTRITO FEDERAL'},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 4,
#       u'distance_mi': 2,
#       u'id': u'ICIUDADD130',
#       u'lat': 19.406687,
#       u'lon': -99.165703,
#       u'neighborhood': u'Taxco',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 4,
#       u'distance_mi': 2,
#       u'id': u'ICIUDADD87',
#       u'lat': 19.430506,
#       u'lon': -99.180405,
#       u'neighborhood': u'Anzures',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 4,
#       u'distance_mi': 2,
#       u'id': u'ICIUDADD40',
#       u'lat': 19.414709,
#       u'lon': -99.177048,
#       u'neighborhood': u'Condesa',
#       u'state': u''},
#      {u'city': u'Mexico City',
#       u'country': u'MX',
#       u'distance_km': 4,
#       u'distance_mi': 2,
#       u'id': u'IMEXICOC20',
#       u'lat': 19.436476,
#       u'lon': -99.184959,
#       u'neighborhood': u'Polanco',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 4,
#       u'distance_mi': 2,
#       u'id': u'ICIUDADD116',
#       u'lat': 19.390839,
#       u'lon': -99.128807,
#       u'neighborhood': u'Avenida Santiago',
#       u'state': u''},
#      {u'city': u'Cuauht\xe9moc',
#       u'country': u'MX',
#       u'distance_km': 5,
#       u'distance_mi': 3,
#       u'id': u'ICUAUHTM4',
#       u'lat': 19.395782,
#       u'lon': -99.164116,
#       u'neighborhood': u'Del Valle Centro',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 5,
#       u'distance_mi': 3,
#       u'id': u'ICIUDADD23',
#       u'lat': 19.429258,
#       u'lon': -99.188828,
#       u'neighborhood': u'Polanco',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MEXICO',
#       u'distance_km': 5,
#       u'distance_mi': 3,
#       u'id': u'IDISTRIT49',
#       u'lat': 19.397875,
#       u'lon': -99.171906,
#       u'neighborhood': u'Napoles Norte',
#       u'state': u'DISTRITO FEDERAL'},
#      {u'city': u'Cuauht\xe9moc',
#       u'country': u'MX',
#       u'distance_km': 5,
#       u'distance_mi': 3,
#       u'id': u'ICUAUHTM2',
#       u'lat': 19.403032,
#       u'lon': -99.179718,
#       u'neighborhood': u'Escand\xf3n',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 5,
#       u'distance_mi': 3,
#       u'id': u'ICIUDADD118',
#       u'lat': 19.397543,
#       u'lon': -99.176544,
#       u'neighborhood': u'Avenida Del Parque',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 5,
#       u'distance_mi': 3,
#       u'id': u'ICIUDADD11',
#       u'lat': 19.407274,
#       u'lon': -99.185562,
#       u'neighborhood': u'San Miguel Chapultepec',
#       u'state': u''},
#      {u'city': u'Cuauht\xe9moc',
#       u'country': u'MX',
#       u'distance_km': 5,
#       u'distance_mi': 3,
#       u'id': u'ICUAUHTM5',
#       u'lat': 19.394934,
#       u'lon': -99.175056,
#       u'neighborhood': u'N\xe1poles',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 5,
#       u'distance_mi': 3,
#       u'id': u'ICIUDADD27',
#       u'lat': 19.428696,
#       u'lon': -99.194359,
#       u'neighborhood': u'Polanco',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 6,
#       u'distance_mi': 3,
#       u'id': u'ICIUDADD42',
#       u'lat': 19.441389,
#       u'lon': -99.197693,
#       u'neighborhood': u'An\xe1huac Dos Lagos',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 6,
#       u'distance_mi': 3,
#       u'id': u'ICIUDADD71',
#       u'lat': 19.442335,
#       u'lon': -99.201408,
#       u'neighborhood': u'Granada',
#       u'state': u''},
#      {u'city': u'Mexico City',
#       u'country': u'MX',
#       u'distance_km': 6,
#       u'distance_mi': 4,
#       u'id': u'IMEXICOC21',
#       u'lat': 19.43441,
#       u'lon': -99.203812,
#       u'neighborhood': u'Polanco',
#       u'state': u''},
#      {u'city': u'Ciudad De M\xe9xico',
#       u'country': u'MX',
#       u'distance_km': 7,
#       u'distance_mi': 4,
#       u'id': u'ICIUDADD39',
#       u'lat': 19.437267,
#       u'lon': -99.209778,
#       u'neighborhood': u'Irrigaci\xf3n',
#       u'state': u''}]}},
#   u'requesturl': u'global/stations/76679.html',
#   u'state': u'',
#   u'type': u'INTLCITY',
#   u'tz_long': u'America/Mexico_City',
#   u'tz_short': u'CST',
#   u'wmo': u'76679',
#   u'wuiurl': u'http://www.wunderground.com/global/stations/76679.html',
#   u'zip': u'00000'},
#  u'response': {u'features': {u'conditions': 1,
#    u'forecast': 1,
#    u'geolookup': 1},
#   u'termsofService': u'http://www.wunderground.com/weather/api/d/terms.html',
#   u'version': u'0.1'}}

# %% [markdown]
# # Ejercicio 1
#
# Modificar el codigo anterior para que la temperatura se imprima en grados Centigrados. _Sugerencia_: Vean el diccionario JSON que regresa el servicio: `parsed_json`

# %% [markdown]
# A continuacion, copien las lineas de codigo a un archivo con extension `.py`. En las libretas es muy facil pues lo unico que tienen que hacer es agregar una instruccion `%%file _nombre_.py`, donde `_nombre_` es el nombre del archivo como quieren guardarlo:

# %%
# %%file tempClase.py
import urllib2
import json

f = urllib2.urlopen('http://api.wunderground.com/api/0def10027afaebb7/geolookup/conditions/forecast/q/Mexico/Mexico.json')
json_string = f.read()
parsed_json = json.loads(json_string)
location = parsed_json['location']['city']
temp_f = parsed_json['current_observation']['temp_f']
print "La temperatura actual en %s es: %s F" % (location, temp_f)
f.close()
# Out:
# Writing tempClase.py

# %% [markdown]
# Pueden verificar que el archivo efectivamente se guardo en su ruta local usando la instruccion `!dir`, la cual usa el comando del OS `dir` para listar los archivos en el folder actual

# %%
# !dir
# Out:
#  El volumen de la unidad C es Windows8_OS
#  El n£mero de serie del volumen es: 8011-D812
#
#  Directorio de C:\Users\Gaspar\Documents\GitHub\lania.ipython\Dia2\notebooks
#
# 31/10/2015  11:19 a. m.    <DIR>          .
# 31/10/2015  11:19 a. m.    <DIR>          ..
# 31/10/2015  11:07 a. m.    <DIR>          .ipynb_checkpoints
# 31/10/2015  09:58 a. m.               525 acelerometro.py
# 31/10/2015  09:58 a. m.            60,541 carota.jpg
# 31/10/2015  10:48 a. m.             4,582 D2L1_Recap.ipynb
# 31/10/2015  11:13 a. m.             5,199 D2L2_Interactuando_con_dispositivo.ipynb
# 31/10/2015  11:17 a. m.            31,997 D2L3_EstadodelTiempo.ipynb
# 31/10/2015  09:58 a. m.            14,285 D2L4_Sensores.ipynb
# 31/10/2015  09:58 a. m.            16,561 D2L5_acelerometro.ipynb
# 31/10/2015  09:58 a. m.           162,001 D2L6_Detectando_rostros.ipynb
# 31/10/2015  09:58 a. m.         1,637,081 D2Ln_InputOutputPython.ipynb
# 31/10/2015  09:58 a. m.             4,794 D2S1L02_Adquiriendo_datos_gps.ipynb
# 31/10/2015  09:58 a. m.           963,439 haarcascade_frontalface_default.xml
# 31/10/2015  09:58 a. m.         1,758,383 maps.html
# 31/10/2015  11:19 a. m.               393 tempClase.py
# 31/10/2015  09:58 a. m.               546 tempMexicoCToastAndDialog.py
# 31/10/2015  09:58 a. m.               393 tempMexicoF.py
# 31/10/2015  09:58 a. m.    <DIR>          Tutoriales
# 31/10/2015  09:58 a. m.             2,472 Untitled.ipynb
# 31/10/2015  09:58 a. m.            70,995 ZuzanaB.jpg
#               17 archivos      4,734,187 bytes
#                4 dirs  588,660,887,552 bytes libres

# %% [markdown]
# Ahora copien el script al dispositivo.

# %%
# !adb push tempClase.py /sdcard/sl4a/scripts
# Out:
# 38 KB/s (393 bytes in 0.009s)

# %% [markdown]
# Revisen su dispositivo, en la lista de scripts deben encontrar el archivo que acaban de copiar. Ejecutenlo y observen lo que ocurre.
#
# # Ejercicio 2
#
# Modificar el script anterior para que la temperatura se despliegue en la pantalla del dispositivo usando primero el metodo `makeToast` y despues una GUI. **NOTA:** usen la informacion de referencia de la APIA: [API Reference](https://github.com/damonkohler/sl4a/blob/wiki/ApiReference.md)
